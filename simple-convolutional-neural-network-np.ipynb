# %% [markdown]
# # Just a simple implementation of a convolutional neural network written in numpy, from the book Grokking Deep Learning

# %% [markdown]
# ### Foward Propagation:

# %%
# Function to select a subregion in a batch of images. It selects the same subregion in a batch of images
def get_image_section(layer, row_from, row_to, col_from, col_to):
    sub_section = layer[:, row_from:row_to, col_from:col_to]
    return sub_section.reshape(-1, 1, row_to-row_from, col_to-col_from)

# %%
layer_0 = images[batch_start:batch_end]
layer_0 = layer_0.reshape(layer_0.shape[0], 28, 28)
layer_0.shape

sects = list()
for row_start in range(layer_0.shape[1] - kernel_rows):
    for col_start in range(layer_0.shape[2] - kernel_cols):
        sect = get_images_section(layer_0,
                                 row_start,
                                 row_start+kernel_rows,
                                 col_start,
                                 col_start+kernel_cols)
        sects.appends(sect)
        
expanded_input = np.concatenate(sects, axis=1)
es = expanded_input.shape
flattened_input = expanded + input.reshape(es[0]*es[1], -1)

# %%
# Randomly initialize the kernels and calculate dot product over the list of subsections
kernels = np.random.random((kernel_rows*kernel_cols, num_kernels))

kernel_output = flattened_input.dot(kernels)

# %% [markdown]
# ### Full implementation:

# %%
import numpy as np, sys
np.random.seed(1)

from keras.datasets import mnist

(x_train, y_train), (x_test, y_test) = mnist.load_data()

images, labels = (x_train[0:1000].reshape(1000, 28*28) / 255,
                y_train[0:1000])

one_hot_labels = np.zeros((len(labels), 10))
for i,l in enumerate(labels):
    one_hot_labels[i][l] = 1
labels = one_hot_labels

test_images = x_test.reshape(len(x_test), 28*28) / 255
test_labels = np.zeros((len(y_test), 10))

for i, l in enumerate(y_test):
    test_labels[i][l] = 1
    
def tanh(x):
    return np.tanh(x)

def tanh2deriv(output):
    return 1 - (output ** 2)

def softmax(x):
    temp = np.exp(x)
    return temp / np.sum(temp, axis=1, keepdims = True)

alpha, iterations = (2, 300)
pixels_per_image, num_labels = (784, 10)
batch_size = 128

input_rows = 28
input_cols = 28

kernel_rows = 3
kernel_cols = 3
num_kernels = 16

hidden_size = ((input_rows - kernel_rows) * (input_cols - kernel_cols)) * num_kernels

kernels = 0.2 * np.random.random((kernel_rows * kernel_cols, num_kernels)) - 0.01

weights_1_2 = 0.2 * np.random.random((hidden_size, num_labels))- 0.1

def get_image_section(layer, row_from, row_to, col_from, col_to):
    section = layer[:, row_from:row_to, col_from:col_to]
    return section.reshape(-1, 1, row_to - row_from, col_to - col_from)

for j in range(iterations):
    correct_cnt = 0
    for i in range(int(len(images) / batch_size)):
        batch_start, batch_end = ((i * batch_size), ((i + 1)* batch_size))
        layer_0 = images[batch_start:batch_end]
        layer_0 = layer_0.reshape(layer_0.shape[0], 28, 28)
        layer_0.shape
        
        sects = list()
        for row_start in range(layer_0.shape[1] - kernel_rows):
            for col_start in range(layer_0.shape[2] - kernel_cols):
                sect = get_image_section(layer_0,
                                        row_start,
                                        row_start+kernel_rows,
                                        col_start,
                                        col_start+kernel_cols)
                sects.append(sect)
                
        expanded_input = np.concatenate(sects, axis = 1)
        es = expanded_input.shape
        flattened_input = expanded_input.reshape(es[0] * es[1], -1)
        
        kernel_output = flattened_input.dot(kernels)
        layer_1 = tanh(kernel_output.reshape(es[0], -1))
        dropout_mask = np.random.randint(2, size= layer_1.shape)
        
        layer_1 *= dropout_mask * 2
        layer_2 = softmax(np.dot(layer_1, weights_1_2))
        
        for k in range(batch_size):
            labelset = labels[batch_start+k:batch_start+k+1]
            _inc = int(np.argmax(layer_2[k:k+1]) == np.argmax(labelset))
            correct_cnt += _inc
            
        layer_2_delta = (labels[batch_start:batch_end] - layer_2) / (batch_size * layer_2.shape[0])
        layer_1_delta = layer_2_delta.dot(weights_1_2.T) * tanh2deriv(layer_1)
        layer_1_delta *= dropout_mask
        weights_1_2 += alpha * layer_1.T.dot(layer_2_delta)
        l1d_reshape = layer_1_delta.reshape(kernel_output.shape)
        k_update = flattened_input.T.dot(l1d_reshape)
        kernels -= alpha * k_update
        
    test_correct_cnt = 0
    
    for i in range(len(test_images)):
        
        layer_0 = test_images[i:i+1]
        layer_0 = layer_0.reshape(layer_0.shape[0], 28, 28)
        layer_0.shape
        
        sects = list()
        for row_start in range(layer_0.shape[1] - kernel_rows):
            for col_start in range(layer_0.shape[2] - kernel_cols):
                sect = get_image_section(layer_0,
                                        row_start,
                                        row_start+kernel_rows,
                                        col_start,
                                        col_start+kernel_cols)
                sects.append(sect)
                
        expanded_input = np.concatenate(sects, axis = 1)
        es = expanded_input.shape
        flattened_input = expanded_input.reshape(es[0] * es[1], -1)
        
        kernel_output = flattened_input.dot(kernels)
        layer_1 = tanh(kernel_output.reshape(es[0], -1))
        layer_2 = np.dot(layer_1, weights_1_2)
        
        test_correct_cnt += int(np.argmax(layer_2) == np.argmax(test_labels[i:i+1]))
        
    if(j % 1 == 0):
        sys.stdout.write("\nI: " + str(j)\
                        + " Test-Acc:" + str(test_correct_cnt/float(len(test_images)))\
                        + " Train-Acc:" + str(correct_cnt/float(len(images))))
# Out:
# I: 0 Test-Acc:0.2425 Train-Acc:0.109
# I: 1 Test-Acc:0.4509 Train-Acc:0.183
# I: 2 Test-Acc:0.5671 Train-Acc:0.298
# I: 3 Test-Acc:0.6439 Train-Acc:0.368
# I: 4 Test-Acc:0.6906 Train-Acc:0.4
# I: 5 Test-Acc:0.7217 Train-Acc:0.466
# I: 6 Test-Acc:0.7429 Train-Acc:0.497
# I: 7 Test-Acc:0.7595 Train-Acc:0.51
# I: 8 Test-Acc:0.7703 Train-Acc:0.568
# I: 9 Test-Acc:0.7807 Train-Acc:0.562
# I: 10 Test-Acc:0.788 Train-Acc:0.568
# I: 11 Test-Acc:0.7938 Train-Acc:0.61
# I: 12 Test-Acc:0.7987 Train-Acc:0.626
# I: 13 Test-Acc:0.8041 Train-Acc:0.64
# I: 14 Test-Acc:0.8059 Train-Acc:0.621
# I: 15 Test-Acc:0.8094 Train-Acc:0.645
# I: 16 Test-Acc:0.8154 Train-Acc:0.64
# I: 17 Test-Acc:0.8196 Train-Acc:0.664
# I: 18 Test-Acc:0.821 Train-Acc:0.676
# I: 19 Test-Acc:0.8246 Train-Acc:0.653
# I: 20 Test-Acc:0.8252 Train-Acc:0.68
# I: 21 Test-Acc:0.8288 Train-Acc:0.684
# I: 22 Test-Acc:0.8295 Train-Acc:0.686
# I: 23 Test-Acc:0.8313 Train-Acc:0.666
# I: 24 Test-Acc:0.8339 Train-Acc:0.687
# I: 25 Test-Acc:0.8336 Train-Acc:0.694
# I: 26 Test-Acc:0.8353 Train-Acc:0.705
# I: 27 Test-Acc:0.8397 Train-Acc:0.7
# I: 28 Test-Acc:0.8389 Train-Acc:0.696
# I: 29 Test-Acc:0.8406 Train-Acc:0.706
# I: 30 Test-Acc:0.8431 Train-Acc:0.686
# I: 31 Test-Acc:0.841 Train-Acc:0.701
# I: 32 Test-Acc:0.8437 Train-Acc:0.703
# I: 33 Test-Acc:0.8457 Train-Acc:0.711
# I: 34 Test-Acc:0.8454 Train-Acc:0.725
# I: 35 Test-Acc:0.8481 Train-Acc:0.724
# I: 36 Test-Acc:0.8499 Train-Acc:0.724
# I: 37 Test-Acc:0.8499 Train-Acc:0.711
# I: 38 Test-Acc:0.8516 Train-Acc:0.734
# I: 39 Test-Acc:0.8525 Train-Acc:0.713
# I: 40 Test-Acc:0.8519 Train-Acc:0.729
# I: 41 Test-Acc:0.8533 Train-Acc:0.723
# I: 42 Test-Acc:0.8553 Train-Acc:0.729
# I: 43 Test-Acc:0.8565 Train-Acc:0.732
# I: 44 Test-Acc:0.8558 Train-Acc:0.735
# I: 45 Test-Acc:0.8531 Train-Acc:0.732
# I: 46 Test-Acc:0.8538 Train-Acc:0.741
# I: 47 Test-Acc:0.8573 Train-Acc:0.731
# I: 48 Test-Acc:0.8585 Train-Acc:0.741
# I: 49 Test-Acc:0.8592 Train-Acc:0.751
# I: 50 Test-Acc:0.8593 Train-Acc:0.734
# I: 51 Test-Acc:0.8576 Train-Acc:0.752
# I: 52 Test-Acc:0.8605 Train-Acc:0.741
# I: 53 Test-Acc:0.8616 Train-Acc:0.752
# I: 54 Test-Acc:0.8634 Train-Acc:0.748
# I: 55 Test-Acc:0.8602 Train-Acc:0.751
# I: 56 Test-Acc:0.8627 Train-Acc:0.742
# I: 57 Test-Acc:0.8629 Train-Acc:0.742
# I: 58 Test-Acc:0.8605 Train-Acc:0.747
# I: 59 Test-Acc:0.8615 Train-Acc:0.751
# I: 60 Test-Acc:0.8622 Train-Acc:0.76
# I: 61 Test-Acc:0.8621 Train-Acc:0.734
# I: 62 Test-Acc:0.862 Train-Acc:0.759
# I: 63 Test-Acc:0.865 Train-Acc:0.758
# I: 64 Test-Acc:0.864 Train-Acc:0.753
# I: 65 Test-Acc:0.8617 Train-Acc:0.756
# I: 66 Test-Acc:0.8633 Train-Acc:0.743
# I: 67 Test-Acc:0.8643 Train-Acc:0.761
# I: 68 Test-Acc:0.8627 Train-Acc:0.753
# I: 69 Test-Acc:0.8666 Train-Acc:0.776
# I: 70 Test-Acc:0.8651 Train-Acc:0.773
# I: 71 Test-Acc:0.8661 Train-Acc:0.76
# I: 72 Test-Acc:0.8654 Train-Acc:0.756
# I: 73 Test-Acc:0.8657 Train-Acc:0.752
# I: 74 Test-Acc:0.8661 Train-Acc:0.769
# I: 75 Test-Acc:0.8672 Train-Acc:0.742
# I: 76 Test-Acc:0.869 Train-Acc:0.775
# I: 77 Test-Acc:0.8661 Train-Acc:0.766
# I: 78 Test-Acc:0.8678 Train-Acc:0.767
# I: 79 Test-Acc:0.8675 Train-Acc:0.77
# I: 80 Test-Acc:0.8687 Train-Acc:0.756
# I: 81 Test-Acc:0.8677 Train-Acc:0.771
# I: 82 Test-Acc:0.8683 Train-Acc:0.766
# I: 83 Test-Acc:0.8709 Train-Acc:0.754
# I: 84 Test-Acc:0.8688 Train-Acc:0.766
# I: 85 Test-Acc:0.8683 Train-Acc:0.762
# I: 86 Test-Acc:0.8669 Train-Acc:0.756
# I: 87 Test-Acc:0.8687 Train-Acc:0.769
# I: 88 Test-Acc:0.8664 Train-Acc:0.783
# I: 89 Test-Acc:0.8719 Train-Acc:0.756
# I: 90 Test-Acc:0.8699 Train-Acc:0.782
# I: 91 Test-Acc:0.8719 Train-Acc:0.781
# I: 92 Test-Acc:0.8705 Train-Acc:0.772
# I: 93 Test-Acc:0.8696 Train-Acc:0.771
# I: 94 Test-Acc:0.8679 Train-Acc:0.761
# I: 95 Test-Acc:0.8679 Train-Acc:0.772
# I: 96 Test-Acc:0.8703 Train-Acc:0.787
# I: 97 Test-Acc:0.8697 Train-Acc:0.781
# I: 98 Test-Acc:0.8717 Train-Acc:0.783
# I: 99 Test-Acc:0.8708 Train-Acc:0.774
# I: 100 Test-Acc:0.8717 Train-Acc:0.763
# I: 101 Test-Acc:0.8703 Train-Acc:0.79
# I: 102 Test-Acc:0.8716 Train-Acc:0.774
# I: 103 Test-Acc:0.8715 Train-Acc:0.779
# I: 104 Test-Acc:0.8705 Train-Acc:0.761
# I: 105 Test-Acc:0.8721 Train-Acc:0.78
# I: 106 Test-Acc:0.8721 Train-Acc:0.794
# I: 107 Test-Acc:0.8717 Train-Acc:0.782
# I: 108 Test-Acc:0.8722 Train-Acc:0.785
# I: 109 Test-Acc:0.8702 Train-Acc:0.803
# I: 110 Test-Acc:0.8727 Train-Acc:0.782
# I: 111 Test-Acc:0.8733 Train-Acc:0.783
# I: 112 Test-Acc:0.8724 Train-Acc:0.783
# I: 113 Test-Acc:0.8734 Train-Acc:0.784
# I: 114 Test-Acc:0.8717 Train-Acc:0.783
# I: 115 Test-Acc:0.8724 Train-Acc:0.784
# I: 116 Test-Acc:0.8722 Train-Acc:0.79
# I: 117 Test-Acc:0.8733 Train-Acc:0.789
# I: 118 Test-Acc:0.8709 Train-Acc:0.766
# I: 119 Test-Acc:0.8737 Train-Acc:0.778
# I: 120 Test-Acc:0.8719 Train-Acc:0.785
# I: 121 Test-Acc:0.8724 Train-Acc:0.79
# I: 122 Test-Acc:0.8716 Train-Acc:0.795
# I: 123 Test-Acc:0.8718 Train-Acc:0.788
# I: 124 Test-Acc:0.8723 Train-Acc:0.788
# I: 125 Test-Acc:0.872 Train-Acc:0.789
# I: 126 Test-Acc:0.873 Train-Acc:0.787
# I: 127 Test-Acc:0.8722 Train-Acc:0.789
# I: 128 Test-Acc:0.8713 Train-Acc:0.791
# I: 129 Test-Acc:0.8721 Train-Acc:0.796
# I: 130 Test-Acc:0.874 Train-Acc:0.801
# I: 131 Test-Acc:0.8726 Train-Acc:0.786
# I: 132 Test-Acc:0.873 Train-Acc:0.803
# I: 133 Test-Acc:0.8733 Train-Acc:0.794
# I: 134 Test-Acc:0.8724 Train-Acc:0.786
# I: 135 Test-Acc:0.8722 Train-Acc:0.794
# I: 136 Test-Acc:0.872 Train-Acc:0.778
# I: 137 Test-Acc:0.8719 Train-Acc:0.788
# I: 138 Test-Acc:0.8727 Train-Acc:0.79
# I: 139 Test-Acc:0.8722 Train-Acc:0.792
# I: 140 Test-Acc:0.8717 Train-Acc:0.79
# I: 141 Test-Acc:0.8734 Train-Acc:0.786
# I: 142 Test-Acc:0.8718 Train-Acc:0.807
# I: 143 Test-Acc:0.873 Train-Acc:0.795
# I: 144 Test-Acc:0.8723 Train-Acc:0.798
# I: 145 Test-Acc:0.8732 Train-Acc:0.797
# I: 146 Test-Acc:0.8741 Train-Acc:0.8
# I: 147 Test-Acc:0.8735 Train-Acc:0.786
# I: 148 Test-Acc:0.8722 Train-Acc:0.811
# I: 149 Test-Acc:0.8736 Train-Acc:0.782
# I: 150 Test-Acc:0.8732 Train-Acc:0.802
# I: 151 Test-Acc:0.8734 Train-Acc:0.786
# I: 152 Test-Acc:0.8732 Train-Acc:0.791
# I: 153 Test-Acc:0.8731 Train-Acc:0.8
# I: 154 Test-Acc:0.8745 Train-Acc:0.816
# I: 155 Test-Acc:0.876 Train-Acc:0.792
# I: 156 Test-Acc:0.8742 Train-Acc:0.792
# I: 157 Test-Acc:0.8728 Train-Acc:0.792
# I: 158 Test-Acc:0.874 Train-Acc:0.791
# I: 159 Test-Acc:0.8744 Train-Acc:0.8
# I: 160 Test-Acc:0.8729 Train-Acc:0.804
# I: 161 Test-Acc:0.8728 Train-Acc:0.802
# I: 162 Test-Acc:0.8746 Train-Acc:0.796
# I: 163 Test-Acc:0.8736 Train-Acc:0.792
# I: 164 Test-Acc:0.8749 Train-Acc:0.795
# I: 165 Test-Acc:0.8735 Train-Acc:0.787
# I: 166 Test-Acc:0.8746 Train-Acc:0.801
# I: 167 Test-Acc:0.8758 Train-Acc:0.807
# I: 168 Test-Acc:0.8739 Train-Acc:0.806
# I: 169 Test-Acc:0.8746 Train-Acc:0.799
# I: 170 Test-Acc:0.875 Train-Acc:0.807
# I: 171 Test-Acc:0.8731 Train-Acc:0.813
# I: 172 Test-Acc:0.8754 Train-Acc:0.804
# I: 173 Test-Acc:0.8744 Train-Acc:0.795
# I: 174 Test-Acc:0.8747 Train-Acc:0.805
# I: 175 Test-Acc:0.8738 Train-Acc:0.808
# I: 176 Test-Acc:0.875 Train-Acc:0.804
# I: 177 Test-Acc:0.8745 Train-Acc:0.807
# I: 178 Test-Acc:0.8753 Train-Acc:0.799
# I: 179 Test-Acc:0.8751 Train-Acc:0.811
# I: 180 Test-Acc:0.874 Train-Acc:0.826
# I: 181 Test-Acc:0.8736 Train-Acc:0.79
# I: 182 Test-Acc:0.8743 Train-Acc:0.819
# I: 183 Test-Acc:0.8725 Train-Acc:0.807
# I: 184 Test-Acc:0.875 Train-Acc:0.805
# I: 185 Test-Acc:0.8745 Train-Acc:0.807
# I: 186 Test-Acc:0.8744 Train-Acc:0.802
# I: 187 Test-Acc:0.8743 Train-Acc:0.815
# I: 188 Test-Acc:0.8743 Train-Acc:0.793
# I: 189 Test-Acc:0.8754 Train-Acc:0.82
# I: 190 Test-Acc:0.8748 Train-Acc:0.792
# I: 191 Test-Acc:0.8716 Train-Acc:0.803
# I: 192 Test-Acc:0.8741 Train-Acc:0.802
# I: 193 Test-Acc:0.8741 Train-Acc:0.792
# I: 194 Test-Acc:0.8727 Train-Acc:0.789
# I: 195 Test-Acc:0.8729 Train-Acc:0.799
# I: 196 Test-Acc:0.8737 Train-Acc:0.785
# I: 197 Test-Acc:0.8722 Train-Acc:0.812
# I: 198 Test-Acc:0.8739 Train-Acc:0.822
# I: 199 Test-Acc:0.8738 Train-Acc:0.806
# I: 200 Test-Acc:0.875 Train-Acc:0.81
# I: 201 Test-Acc:0.8752 Train-Acc:0.797
# I: 202 Test-Acc:0.8746 Train-Acc:0.818
# I: 203 Test-Acc:0.8742 Train-Acc:0.811
# I: 204 Test-Acc:0.8754 Train-Acc:0.806
# I: 205 Test-Acc:0.8742 Train-Acc:0.805
# I: 206 Test-Acc:0.8733 Train-Acc:0.808
# I: 207 Test-Acc:0.8741 Train-Acc:0.805
# I: 208 Test-Acc:0.8743 Train-Acc:0.817
# I: 209 Test-Acc:0.8738 Train-Acc:0.815
# I: 210 Test-Acc:0.8731 Train-Acc:0.798
# I: 211 Test-Acc:0.8738 Train-Acc:0.823
# I: 212 Test-Acc:0.8726 Train-Acc:0.816
# I: 213 Test-Acc:0.8741 Train-Acc:0.809
# I: 214 Test-Acc:0.8733 Train-Acc:0.812
# I: 215 Test-Acc:0.8741 Train-Acc:0.81
# I: 216 Test-Acc:0.8739 Train-Acc:0.8
# I: 217 Test-Acc:0.8723 Train-Acc:0.809
# I: 218 Test-Acc:0.8719 Train-Acc:0.82
# I: 219 Test-Acc:0.874 Train-Acc:0.821
# I: 220 Test-Acc:0.8734 Train-Acc:0.81
# I: 221 Test-Acc:0.8724 Train-Acc:0.805
# I: 222 Test-Acc:0.8721 Train-Acc:0.807
# I: 223 Test-Acc:0.8722 Train-Acc:0.797
# I: 224 Test-Acc:0.8716 Train-Acc:0.813
# I: 225 Test-Acc:0.8722 Train-Acc:0.813
# I: 226 Test-Acc:0.8741 Train-Acc:0.803
# I: 227 Test-Acc:0.8743 Train-Acc:0.812
# I: 228 Test-Acc:0.8745 Train-Acc:0.804
# I: 229 Test-Acc:0.8743 Train-Acc:0.817
# I: 230 Test-Acc:0.8718 Train-Acc:0.802
# I: 231 Test-Acc:0.8725 Train-Acc:0.817
# I: 232 Test-Acc:0.8721 Train-Acc:0.819
# I: 233 Test-Acc:0.8729 Train-Acc:0.809
# I: 234 Test-Acc:0.8722 Train-Acc:0.819
# I: 235 Test-Acc:0.8722 Train-Acc:0.812
# I: 236 Test-Acc:0.873 Train-Acc:0.805
# I: 237 Test-Acc:0.8729 Train-Acc:0.81
# I: 238 Test-Acc:0.8718 Train-Acc:0.816
# I: 239 Test-Acc:0.8711 Train-Acc:0.803
# I: 240 Test-Acc:0.8718 Train-Acc:0.814
# I: 241 Test-Acc:0.8721 Train-Acc:0.812
# I: 242 Test-Acc:0.8726 Train-Acc:0.81
# I: 243 Test-Acc:0.8732 Train-Acc:0.812
# I: 244 Test-Acc:0.8725 Train-Acc:0.811
# I: 245 Test-Acc:0.8742 Train-Acc:0.812
# I: 246 Test-Acc:0.8731 Train-Acc:0.807
# I: 247 Test-Acc:0.8726 Train-Acc:0.817
# I: 248 Test-Acc:0.8718 Train-Acc:0.816
# I: 249 Test-Acc:0.8727 Train-Acc:0.814
# I: 250 Test-Acc:0.8729 Train-Acc:0.82
# I: 251 Test-Acc:0.8727 Train-Acc:0.817
# I: 252 Test-Acc:0.8739 Train-Acc:0.809
# I: 253 Test-Acc:0.871 Train-Acc:0.815
# I: 254 Test-Acc:0.8733 Train-Acc:0.803
# I: 255 Test-Acc:0.8722 Train-Acc:0.817
# I: 256 Test-Acc:0.8721 Train-Acc:0.825
# I: 257 Test-Acc:0.8733 Train-Acc:0.828
# I: 258 Test-Acc:0.8727 Train-Acc:0.816
# I: 259 Test-Acc:0.8729 Train-Acc:0.812
# I: 260 Test-Acc:0.8728 Train-Acc:0.815
# I: 261 Test-Acc:0.8726 Train-Acc:0.814
# I: 262 Test-Acc:0.8735 Train-Acc:0.819
# I: 263 Test-Acc:0.8736 Train-Acc:0.819
# I: 264 Test-Acc:0.8719 Train-Acc:0.805
# I: 265 Test-Acc:0.8717 Train-Acc:0.808
# I: 266 Test-Acc:0.872 Train-Acc:0.818
# I: 267 Test-Acc:0.8729 Train-Acc:0.809
# I: 268 Test-Acc:0.8726 Train-Acc:0.82
# I: 269 Test-Acc:0.871 Train-Acc:0.816
# I: 270 Test-Acc:0.8714 Train-Acc:0.818
# I: 271 Test-Acc:0.8723 Train-Acc:0.818
# I: 272 Test-Acc:0.8699 Train-Acc:0.817
# I: 273 Test-Acc:0.8701 Train-Acc:0.816
# I: 274 Test-Acc:0.871 Train-Acc:0.816
# I: 275 Test-Acc:0.8712 Train-Acc:0.809
# I: 276 Test-Acc:0.871 Train-Acc:0.827
# I: 277 Test-Acc:0.8726 Train-Acc:0.821
# I: 278 Test-Acc:0.8712 Train-Acc:0.811
# I: 279 Test-Acc:0.8732 Train-Acc:0.819
# I: 280 Test-Acc:0.8728 Train-Acc:0.816
# I: 281 Test-Acc:0.8718 Train-Acc:0.813
# I: 282 Test-Acc:0.871 Train-Acc:0.806
# I: 283 Test-Acc:0.8705 Train-Acc:0.818
# I: 284 Test-Acc:0.8728 Train-Acc:0.827
# I: 285 Test-Acc:0.8746 Train-Acc:0.819
# I: 286 Test-Acc:0.873 Train-Acc:0.832
# I: 287 Test-Acc:0.8719 Train-Acc:0.813
# I: 288 Test-Acc:0.8713 Train-Acc:0.809
# I: 289 Test-Acc:0.8721 Train-Acc:0.815
# I: 290 Test-Acc:0.8716 Train-Acc:0.811
# I: 291 Test-Acc:0.8708 Train-Acc:0.819
# I: 292 Test-Acc:0.8719 Train-Acc:0.823
# I: 293 Test-Acc:0.8709 Train-Acc:0.818
# I: 294 Test-Acc:0.8689 Train-Acc:0.816
# I: 295 Test-Acc:0.8684 Train-Acc:0.822
# I: 296 Test-Acc:0.8707 Train-Acc:0.825
# I: 297 Test-Acc:0.8698 Train-Acc:0.819
# I: 298 Test-Acc:0.8701 Train-Acc:0.818
# I: 299 Test-Acc:0.8698 Train-Acc:0.802
